# %% [markdown]
# 1) Considere o seguinte trecho de código, parte do preenchimento do perfil de investidor do banco:
#
# i = input('Você sabe o que é uma RENDA FIXA?: ')
# Caso o usuário digite na caixa de texto de entrada "True", qual será o tipo de dado da variável i?
#
# a) int
#
# b) str
#
# c) float
#
# d) bool
#
# e) list
#
# # Resposta = b) str ; No Python, a função input() sempre retorna uma string. Mesmo que o usuário digite “True”, vai ser interpretado como uma string, não como um valor booleano. Pra converter a entrada do usuário em um booleano, eu precisaria usar a função bool(). No entanto, isso pode não funcionar como esperado com a string “True”, porque bool("True") e bool("False") retornariam ambos True, já que qualquer string não vazia é considerada True quando convertida para um booleano. Para obter o comportamento desejado, eu precisaria verificar explicitamente se a entrada do usuário é igual a “True”.

# %% [markdown]
# 2) Você precisa implementar um código em Python que solicite ao usuário o valor principal (capital) inicial, a taxa de juros por período e o tempo em que o dinheiro é emprestado ou investido. Com base nesses valores, o programa deve calcular os juros simples e o montante total ao final do período. Assuma que temos apenas um único mês de investimento/empréstimo. Assinale a alternativa que corretamente implementa este procedimento:
#
# a) juros = principal *= taxa
# montante = principal + juros
#
# b) juros = principal * taxa
# montante = principal += juros
#
# c) juros = principal *= taxa
# montante = principal += juros
#
# d) juros = principal + taxa
# montante == principal ** juros
#
# Dica: O montante é calculado somando o principal ao juros e os juros são o produto do principal pela taxa.
#
# # Resposta = e) juros = principal * taxa
# # montante = principal + juros ;

# %%
principal = float(input("Digite o valor principal: "))
taxa = float(input("Digite a taxa de juros por período: "))

juros = principal * taxa

montante = principal + juros

print("Os juros são: ", juros)
print("O montante total ao final do período é: ", montante)
# Out:
# Os juros são:  1645.0
# O montante total ao final do período é:  1680.0

# %% [markdown]
# 3) Na variável clientes_ano temos uma lista de listas, em que cada elemento é uma lista de dois elementos, o primeiro é o nome do cliente cadastrado na plataforma, e o segundo é o ano em que o cadastro foi realizado. Você deseja criar uma nova lista de listas (chamade de clientes_relacionamento), em que cada elemento é uma lista de dois elementos, sendo o primeiro o nome do cliente (como é na lista original), e o segundo é o número de anos em que o cliente está cadastrado na plataforma (considere que o ano atual é 2023). Qual das alternativas a seguir completa corretamente o trecho de código iniciado abaixo, para construir corretamente a lista desejada?
#
# clientes_ano = [['Cliente A', 2018], ['Cliente B', 2021]] # Este é apenas um exemplo da lista dos anos
# clientes_relacionamento = []
#
# for lista in clientes_ano:
#
#     clientes_relacionamento.append([lista[0], 2023 - lista[1]])
#
# Ao revisar este código, qual das alternativas a seguir produz o mesmo resultado?
#
# a) clientes_relacionamento.append([lista[0], lista[1] - 2023])
#
# b) clientes_relacionamento.append([lista[1], 2023 - lista[0]])
#
# c) clientes_relacionamento.append([lista[1], lista[0] - 2023])
#
# d) clientes_relacionamento.append([lista, 2023 - lista])
#
# e) clientes_relacionamento.append([lista[0], 2023 - lista[1]])
#
# # Resposta = e) clientes_relacionamento.append([lista[0], 2023 - lista[1]])

# %% [markdown]
# 4) Queremos criar uma lista para armazenar os preços dos produtos de determinado banco. Em qual das opções abaixo a variável precos_produtos não é uma lista?
#
# a) precos_produtos = []
#
# b) precos_produtos = list("1 2 3 4")
#
# c) precos_produtos = (1, 1.5, 3.8)
#
# d) precos_produtos = [1, 2, 3, 4]
#
# e) precos_produtos = list()
#
# # Resposta = c) precos_produtos = (1, 1.5, 3.8).
#
# # Nessa resposta, precos_produtos é uma tupla e não uma lista. As tuplas são semelhantes às listas, mas são imutáveis. As tuplas são definidas usando parênteses (), enquanto as listas são definidas quando usamos colchetes []. E todas as outras opções criam listas.

# %% [markdown]
# 5) Em um banco, existe um sistema de alerta na central de suporte que é ativado quando o número de chamados supera 500. Enquanto o volume de chamados permanecer acima desse limite, o sistema exibe uma mensagem indicando quantos chamados ainda precisam ser resolvidos para que o número volte a ficar adequado. Para implementar esta lógica, você começou criando o seguinte código:
#
# num_chamados = 780
#
# while (num_chamados > 500):
#
#     print(f'ALERTA! HÁ UM TOTAL DE {num_chamados}')
#
#     print('Você atendeu um chamado!')
#
#     print(f"Faltam {num_chamados - 500} para o nível estar dentro do aceitável!")
#
#     num_chamados -= 1.
#
# print("\nNão estamos mais em estado de alerta!")
#
# # Assinale a alternativa que implementa corretamente a lógica desejada, substituindo o comentário no código acima:
#
# a) num_chamados += 1
#
# b) num_chamados = 100 - num_chamados
#
# c) num_chamados -= 1
#
# d) num_chamados = 100 + num_chamados
#
# e) num_chamados += 100
#
# # Resposta = c) num_chamados -= 1.

# %%
num_chamados = 780

while (num_chamados > 500):

    print(f'ALERTA! HÁ UM TOTAL DE {num_chamados}')

    print('Você atendeu um chamado!')

    print(f"Faltam {num_chamados - 500} para o nível estar dentro do aceitável!")

    num_chamados -= 1.

print("\nNão estamos mais em estado de alerta!")
# Out:
# ALERTA! HÁ UM TOTAL DE 780
# Você atendeu um chamado!
# Faltam 280 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 779.0
# Você atendeu um chamado!
# Faltam 279.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 778.0
# Você atendeu um chamado!
# Faltam 278.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 777.0
# Você atendeu um chamado!
# Faltam 277.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 776.0
# Você atendeu um chamado!
# Faltam 276.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 775.0
# Você atendeu um chamado!
# Faltam 275.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 774.0
# Você atendeu um chamado!
# Faltam 274.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 773.0
# Você atendeu um chamado!
# Faltam 273.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 772.0
# Você atendeu um chamado!
# Faltam 272.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 771.0
# Você atendeu um chamado!
# Faltam 271.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 770.0
# Você atendeu um chamado!
# Faltam 270.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 769.0
# Você atendeu um chamado!
# Faltam 269.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 768.0
# Você atendeu um chamado!
# Faltam 268.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 767.0
# Você atendeu um chamado!
# Faltam 267.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 766.0
# Você atendeu um chamado!
# Faltam 266.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 765.0
# Você atendeu um chamado!
# Faltam 265.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 764.0
# Você atendeu um chamado!
# Faltam 264.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 763.0
# Você atendeu um chamado!
# Faltam 263.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 762.0
# Você atendeu um chamado!
# Faltam 262.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 761.0
# Você atendeu um chamado!
# Faltam 261.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 760.0
# Você atendeu um chamado!
# Faltam 260.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 759.0
# Você atendeu um chamado!
# Faltam 259.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 758.0
# Você atendeu um chamado!
# Faltam 258.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 757.0
# Você atendeu um chamado!
# Faltam 257.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 756.0
# Você atendeu um chamado!
# Faltam 256.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 755.0
# Você atendeu um chamado!
# Faltam 255.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 754.0
# Você atendeu um chamado!
# Faltam 254.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 753.0
# Você atendeu um chamado!
# Faltam 253.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 752.0
# Você atendeu um chamado!
# Faltam 252.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 751.0
# Você atendeu um chamado!
# Faltam 251.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 750.0
# Você atendeu um chamado!
# Faltam 250.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 749.0
# Você atendeu um chamado!
# Faltam 249.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 748.0
# Você atendeu um chamado!
# Faltam 248.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 747.0
# Você atendeu um chamado!
# Faltam 247.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 746.0
# Você atendeu um chamado!
# Faltam 246.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 745.0
# Você atendeu um chamado!
# Faltam 245.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 744.0
# Você atendeu um chamado!
# Faltam 244.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 743.0
# Você atendeu um chamado!
# Faltam 243.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 742.0
# Você atendeu um chamado!
# Faltam 242.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 741.0
# Você atendeu um chamado!
# Faltam 241.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 740.0
# Você atendeu um chamado!
# Faltam 240.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 739.0
# Você atendeu um chamado!
# Faltam 239.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 738.0
# Você atendeu um chamado!
# Faltam 238.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 737.0
# Você atendeu um chamado!
# Faltam 237.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 736.0
# Você atendeu um chamado!
# Faltam 236.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 735.0
# Você atendeu um chamado!
# Faltam 235.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 734.0
# Você atendeu um chamado!
# Faltam 234.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 733.0
# Você atendeu um chamado!
# Faltam 233.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 732.0
# Você atendeu um chamado!
# Faltam 232.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 731.0
# Você atendeu um chamado!
# Faltam 231.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 730.0
# Você atendeu um chamado!
# Faltam 230.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 729.0
# Você atendeu um chamado!
# Faltam 229.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 728.0
# Você atendeu um chamado!
# Faltam 228.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 727.0
# Você atendeu um chamado!
# Faltam 227.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 726.0
# Você atendeu um chamado!
# Faltam 226.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 725.0
# Você atendeu um chamado!
# Faltam 225.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 724.0
# Você atendeu um chamado!
# Faltam 224.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 723.0
# Você atendeu um chamado!
# Faltam 223.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 722.0
# Você atendeu um chamado!
# Faltam 222.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 721.0
# Você atendeu um chamado!
# Faltam 221.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 720.0
# Você atendeu um chamado!
# Faltam 220.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 719.0
# Você atendeu um chamado!
# Faltam 219.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 718.0
# Você atendeu um chamado!
# Faltam 218.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 717.0
# Você atendeu um chamado!
# Faltam 217.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 716.0
# Você atendeu um chamado!
# Faltam 216.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 715.0
# Você atendeu um chamado!
# Faltam 215.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 714.0
# Você atendeu um chamado!
# Faltam 214.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 713.0
# Você atendeu um chamado!
# Faltam 213.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 712.0
# Você atendeu um chamado!
# Faltam 212.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 711.0
# Você atendeu um chamado!
# Faltam 211.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 710.0
# Você atendeu um chamado!
# Faltam 210.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 709.0
# Você atendeu um chamado!
# Faltam 209.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 708.0
# Você atendeu um chamado!
# Faltam 208.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 707.0
# Você atendeu um chamado!
# Faltam 207.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 706.0
# Você atendeu um chamado!
# Faltam 206.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 705.0
# Você atendeu um chamado!
# Faltam 205.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 704.0
# Você atendeu um chamado!
# Faltam 204.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 703.0
# Você atendeu um chamado!
# Faltam 203.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 702.0
# Você atendeu um chamado!
# Faltam 202.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 701.0
# Você atendeu um chamado!
# Faltam 201.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 700.0
# Você atendeu um chamado!
# Faltam 200.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 699.0
# Você atendeu um chamado!
# Faltam 199.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 698.0
# Você atendeu um chamado!
# Faltam 198.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 697.0
# Você atendeu um chamado!
# Faltam 197.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 696.0
# Você atendeu um chamado!
# Faltam 196.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 695.0
# Você atendeu um chamado!
# Faltam 195.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 694.0
# Você atendeu um chamado!
# Faltam 194.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 693.0
# Você atendeu um chamado!
# Faltam 193.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 692.0
# Você atendeu um chamado!
# Faltam 192.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE
0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 514.0
# Você atendeu um chamado!
# Faltam 14.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 513.0
# Você atendeu um chamado!
# Faltam 13.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 512.0
# Você atendeu um chamado!
# Faltam 12.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 511.0
# Você atendeu um chamado!
# Faltam 11.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 510.0
# Você atendeu um chamado!
# Faltam 10.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 509.0
# Você atendeu um chamado!
# Faltam 9.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 508.0
# Você atendeu um chamado!
# Faltam 8.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 507.0
# Você atendeu um chamado!
# Faltam 7.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 506.0
# Você atendeu um chamado!
# Faltam 6.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 505.0
# Você atendeu um chamado!
# Faltam 5.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 504.0
# Você atendeu um chamado!
# Faltam 4.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 503.0
# Você atendeu um chamado!
# Faltam 3.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 502.0
# Você atendeu um chamado!
# Faltam 2.0 para o nível estar dentro do aceitável!
# ALERTA! HÁ UM TOTAL DE 501.0
# Você atendeu um chamado!
# Faltam 1.0 para o nível estar dentro do aceitável!
#
# Não estamos mais em estado de alerta!

# %% [markdown]
# 6) Imagine que você está desenvolvendo um aplicativo para planejamento de viagens rodoviárias. Uma das funcionalidades desse aplicativo é ajudar os usuários a estimar o tempo que levarão para chegar a seus destinos. Para tornar o aplicativo mais interativo e educativo, você decide incluir uma seção onde os usuários podem calcular a distância de uma viagem baseando-se na velocidade média esperada do veículo e no tempo de viagem. Faça um código em Python que calcule a distância em km entre duas cidades, completando o template de código a seguir, no qual o tempo em minutos deve ser informado pelo usuário:
#
# velocidade = 25 # esta em m/s
#
# velocidade_convertida = # código para colocar a velocidade na unidade adequada
#
# tempo = # código para receber como input do usuário o tempo em minutos
#
# distancia = # código que implementa a lógica da distância em km
#
# print(f"\nA distância entre os dois locais é {distancia} km!")
# Dica 1: o tempo necessário para percorrer uma dada distância à velocidade constante é dado pelo quociente entre a distância e a velocidade.
#
# Dica 2: 1 m/s = 3,6 km/h. Atenção às unidades!

# %%
velocidade = 25 

velocidade_convertida = velocidade * 3.6 

tempo = float(input("Digite o tempo de viagem em minutos: "))

tempo_em_horas = tempo / 60 

distancia = velocidade_convertida * tempo_em_horas

print(f"\nA distância entre os dois locais é {distancia:.2f} km!")
# Out:
# A distância entre os dois locais é 37.50 km!

# %% [markdown]
# 7) Em um banco, é importante que tenhamos um registro de todos os clientes, sejam correntistas ou não, para que seja possível, por exemplo, realizar a comunicação com eles enviando ofertas de produtos.
#
# Para começar a prototipar esta funcionalidade, você deve criar um programa em Python que leia diversos números inteiros e insira todos em uma lista (esses números são os identificadores dos clientes). A cada solicitação de número, pergunte ao usuário se deseja inserir outro número: tendo como resposta 'S' para inserir mais um; ou 'N' caso queira terminar. É possível que o mesmo número seja digitado mais de uma vez (isso pode representar o mesmo cliente fazendo mais de um pedido). Após construir a lista, mostre:
#
# a) todos os números digitados na ordem em que foram inseridos
#
# b) todos os números digitados em ordem crescente
#
# c) a média destes valores
#
# d) apenas os números pares
#
# e) apenas os números ímpares
#
# f) apenas os números repetidos
#
# Obs.: O usuário obrigatoriamente digitará as letras S e N, contudo não necessariamente de forma padronizada.

# %%
clientes = []

while True:
    numero = int(input("Digite o identificador do cliente: "))

    clientes.append(numero)

    continuar = input("Deseja inserir outro número? (S/N): ").upper()

    if continuar != 'S':
        break

print("Números digitados na ordem de inserção:", clientes)

clientes_ordenados = sorted(clientes)
print("Números digitados em ordem crescente:", clientes_ordenados)

media = sum(clientes) / len(clientes)
print("Média dos valores:", media)

numeros_pares = [num for num in clientes if num % 2 == 0]
print("Números pares:", numeros_pares)

numeros_impares = [num for num in clientes if num % 2 != 0]
print("Números ímpares:", numeros_impares)

numeros_repetidos = [num for num in set(clientes) if clientes.count(num) > 1]
print("Números repetidos:", numeros_repetidos)
# Out:
# Números digitados na ordem de inserção: [10, 10, 10]
# Números digitados em ordem crescente: [10, 10, 10]
# Média dos valores: 10.0
# Números pares: [10, 10, 10]
# Números ímpares: []
# Números repetidos: [10]

# %% [markdown]
# 8) Escreva um código em Python que recebe um número (que possa ter casas decimais) e a escala de temperatura em que este valor se encontra e para qual ele deseja converter (Celsius, Kelvin ou Fahrenheit). Tanto na escala em que se encontra quanto para a que deseja converter, utilize as letras iniciais como entrada: Celsius - 'C', Kelvin - 'K' ou Fahrenheit - 'F'.
#
# Seu código deve solicitar ao usuário as informações necessárias para realizar a conversão de temperatura (temperatura, escala_original, escala_convertida), de acordo com o template abaixo.
#
# temperatura = # código para receber o valor numérico da temperatura desejada
#
# escala_original = # código para receber a escala original da temperatura informada
#
# escala_convertida = # código para receber a escala para a qual deseja-se converter a temperatura
# Implemente abaixo toda a lógica de conversão de temperaturas, bem como as validações necessárias.
#
# Importante: o programa deve trabalhar apenas com as 3 escalas supracitadas! Então, não deixe de fazer as validações necessárias. Além disso, por definição, não existem temperaturas em Kelvin abaixo de zero (o valor zero pode existir), portanto verifique também esta condição para que sejam feitas conversões válidas!
#
# Dica: as equações de conversão entre as escalas são as seguintes:
#
# Celsius <> Fahrenheit: \color{white}{\frac{C}{5} = \frac{F - 32}{9}}
#
# Celsius <> Kelvin:  \color{white}{C = K - 273}
#
# Kelvin <> Fahrenheit:  \color{white}{\frac{K - 273}{5} = \frac{F - 32}{9}}

# %%
temperatura = float(input("Digite a temperatura: "))

escala_original = input("Digite a escala da temperatura (C, K, ou F): ").upper()

escala_convertida = input("Digite a escala para a qual deseja converter (C, K, ou F): ").upper()

escalas_validas = ['C', 'K', 'F']
if escala_original not in escalas_validas or escala_convertida not in escalas_validas:
    print("Por favor, insira escalas válidas: C, K ou F.")
else:

    if escala_original == 'C':
        if escala_convertida == 'F':
            temperatura_convertida = (temperatura * 9/5) + 32
        elif escala_convertida == 'K':
            temperatura_convertida = temperatura + 273
        else:
            temperatura_convertida = temperatura  
    elif escala_original == 'F':
        if escala_convertida == 'C':
            temperatura_convertida = (temperatura - 32) * 5/9
        elif escala_convertida == 'K':
            temperatura_convertida = (temperatura + 459.67) * 5/9
        else:
            temperatura_convertida = temperatura 
    else: 
        if escala_convertida == 'C':
            temperatura_convertida = temperatura - 273
        elif escala_convertida == 'F':
            temperatura_convertida = (temperatura * 9/5) - 459.67
        else:
            temperatura_convertida = temperatura 
            
    print(f"\nA temperatura convertida é: {temperatura_convertida:.2f} {escala_convertida}")
# Out:
# A temperatura convertida é: 348.00 K

# %% [markdown]
# 9) Um grande banco deseja saber quais são seus produtos mais vendidos. Em uma lista, são registrados os nomes dos produtos, na ordem em que eles são vendidos (portanto, há elementos repetidos nesta lista). Faça um programa que exibe na tela cada um dos produtos na lista de input, e a quantidade em que eles foram vendidos (separados por um traço), de modo que teremos uma mensagem em cada linha. Os produtos devem ser exibidos em ordem alfabética.
#
# Ex.: para a lista produtos = ["Crediário", "Consórcio", "Consórcio", "Financiamento", "Consórcio", "Crediário"]
#
# Obs: Existem outros produtos além dos da lista acima, seu código deve contemplar outras possibilidades.
#
# Devemos ter as seguintes mensagens exibidas na tela:
#
# Consórcio - 3
# Crediário - 2
# Financiamento - 1

# %%
def produtos_mais_vendidos(produtos):
    contagem = {}
    for produto in produtos:
        if produto in contagem:
            contagem[produto] += 1
        else:
            contagem[produto] = 1

    for produto in sorted(contagem):
        print(f'{produto} - {contagem[produto]}')

produtos = ["Crediário", "Consórcio", "Consórcio", "Financiamento", "Consórcio", "Crediário"]
produtos_mais_vendidos(produtos)
# Out:
# Consórcio - 3
# Crediário - 2
# Financiamento - 1

# %% [markdown]
# 10) Um banco está analisando o desempenho de um investimento ao longo de um mês. Eles têm uma lista de valores de fechamento diários deste investimento e querem calcular uma média móvel de 7 dias para entender melhor as tendências no curto prazo. A média móvel de 7 dias é uma forma comum de suavizar flutuações diárias, dando ao banco uma visão mais clara das tendências de desempenho do investimento.
#
# Seu objetivo é desenvolver um código em Python que processe a lista de valores fornecida. O código deve calcular e retornar uma nova lista contendo a média móvel de 7 dias para cada período possível dentro dos dados fornecidos.
#
# Dica: A média móvel em um determinado dia é calculada como a média dos valores de fechamento dos 7 dias anteriores, incluindo o dia atual.
#
# valores_dos_fechamentos = [
#     156.89, 155.16, 148.41, 145.18, 150.23, 148.10, 155.68,
#     146.07, 149.53, 151.67, 158.16, 150.09, 145.64, 155.12,
#     152.37, 145.01, 158.19, 159.66, 156.20, 158.04, 146.20,
#     154.60, 157.98, 153.68, 149.44, 142.01, 148.68, 152.22,
#     158.26, 159.33
# ]

# %%
valores_dos_fechamentos = [
    156.89, 155.16, 148.41, 145.18, 150.23, 148.10, 155.68,
    146.07, 149.53, 151.67, 158.16, 150.09, 145.64, 155.12,
    152.37, 145.01, 158.19, 159.66, 156.20, 158.04, 146.20,
    154.60, 157.98, 153.68, 149.44, 142.01, 148.68, 152.22,
    158.26, 159.33
]

def media_movel_7dias(valores):
    media_movel = []
    for i in range(6, len(valores)):
        media = sum(valores[i-6:i+1]) / 7
        media_movel.append(media)
    return media_movel

resultado_media_movel = media_movel_7dias(valores_dos_fechamentos)

print("Média Móvel de 7 dias:")
for i, media in enumerate(resultado_media_movel, start=7):
    print(f"Dia {i}: {media:.2f}")
# Out:
# Média Móvel de 7 dias:
# Dia 7: 151.38
# Dia 8: 149.83
# Dia 9: 149.03
# Dia 10: 149.49
# Dia 11: 151.35
# Dia 12: 151.33
# Dia 13: 150.98
# Dia 14: 150.90
# Dia 15: 151.80
# Dia 16: 151.15
# Dia 17: 152.08
# Dia 18: 152.30
# Dia 19: 153.17
# Dia 20: 154.94
# Dia 21: 153.67
# Dia 22: 153.99
# Dia 23: 155.84
# Dia 24: 155.19
# Dia 25: 153.73
# Dia 26: 151.71
# Dia 27: 150.37
# Dia 28: 151.23
# Dia 29: 151.75
# Dia 30: 151.95
